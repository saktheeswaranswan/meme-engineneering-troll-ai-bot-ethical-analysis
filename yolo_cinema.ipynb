# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 23.7 MB/s eta 0:00:00
# ...

# %%
# -*- coding: utf-8 -*-
"""yolosasvemovieanno.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1kSc_9Jvijez1ze-Vt1FL-Lxk-HEkhzbx
"""

import os
import cv2
import json
import numpy as np
from ultralytics import YOLO

# Ensure output directory exists
output_dir = "output"
os.makedirs(output_dir, exist_ok=True)

# Load the YOLOv11x-pose model (highest accuracy)
model = YOLO("/content/yolo11x-pose.pt")  # ensure this file is available

# Open video source (replace with 0 for webcam or a file path)
cap = cv2.VideoCapture("/content/drive/MyDrive/myss/appp.mp4")
if not cap.isOpened():
    raise IOError("Cannot open video file")

# Video properties and output setup (HD 1280x720)
fps    = cap.get(cv2.CAP_PROP_FPS)
width  = 1280
height = 720
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter("output/dttttice.mp4", fourcc, fps, (width, height))

pose_data = []
frame_count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break  # end of video

    # Resize frame to 1280x720
    frame = cv2.resize(frame, (width, height))

    # Run pose estimation with tracking enabled
    results = model.track(frame, task="pose", persist=True)
    res = results[0]  # result for the current frame

    # Draw skeletons/keypoints on the frame
    annotated_frame = res.plot()

    # If there are detections, extract their data
    if res.boxes is not None and len(res.boxes.xyxy):
        # Get tracking IDs (one per detected person)
        if res.boxes.id is not None:
            track_ids = res.boxes.id.int().cpu().numpy().tolist()
        else:
            track_ids = [None] * len(res.boxes.xyxy)

        # Iterate over each detected person i
        for i, bbox in enumerate(res.boxes.xyxy):
            person_id = int(track_ids[i]) if track_ids[i] is not None else None
            # 17 x [x, y] keypoint coordinates
            keypoints = res.keypoints.xy[i].cpu().numpy().tolist()
            # Bounding box [x_min, y_min, x_max, y_max]
            bbox_xyxy = bbox.cpu().numpy().tolist()

            frame_data = {
                "frame_id": frame_count,
                "person_id": person_id,
                "keypoints": keypoints,
                "bounding_box": bbox_xyxy
            }
            pose_data.append(frame_data)

    # Write the annotated frame to output video
    out.write(annotated_frame)
    frame_count += 1

# Release resources
cap.release()
out.release()

# Save all pose data to JSON file
with open("output/pose_data.json", "w") as f:
    json.dump(pose_data, f, indent=4)

print("✅ Annotated video saved as output/annotated_output.mp4")
print("✅ Pose data saved as output/pottse_data.json")

#!git clone https://github.com/ultralytics/ultralytics.git

#!wget https://huggingface.co/Ultralytics/YOLO11/resolve/1d41cfddc10550b04b71ce479a791cc3e772a15d/yolo11x-pose.pt

#!pip install ultralytics
# Out:
# Streaming output truncated to the last 5000 lines.
#
# 0: 384x640 1 person, 39.9ms
# Speed: 2.2ms preprocess, 39.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 39.3ms
# Speed: 5.1ms preprocess, 39.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 39.4ms
# Speed: 4.2ms preprocess, 39.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 43.4ms
# Speed: 3.2ms preprocess, 43.4ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 41.4ms
# Speed: 3.2ms preprocess, 41.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 39.3ms
# Speed: 2.2ms preprocess, 39.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 40.7ms
# Speed: 2.9ms preprocess, 40.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
# !pip install -U yt-dlp
import os

# YouTube URL
url = "https://www.youtube.com/watch?v=iNp8zFd5r8Y"

# Download the best quality mp4 format
os.system(f'yt-dlp -f "bestvideo[ext=mp4]+bestaudio[ext=m4a]/mp4" -o "input_video.mp4" {url}')

# Check the file exists
import os
if os.path.exists("input_video.mp4"):
    print("✅ Video downloaded successfully!")
else:
    print("❌ Video download failed.")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.0/176.0 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 72.2 MB/s eta 0:00:00
# ...
# ✅ Video downloaded successfully!

# %%
# !mv /content/output/huttithare.json  /content/drive/MyDrive/myss

# %%
# !wget https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11x-pose.pt
# Out:
# --2025-11-10 15:18:08--  https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11x-pose.pt
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !mv /content/output/apacalyptoaianalyisis.json   /content/drive/MyDrive/myss
